# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
df=pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df["rate"].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df["rate"] = df["rate"].fillna(df["rate"].mode()[0])
df['rate'].isnull().sum()
# Out:
# 0

# %%
rate_hyphen = df.loc[df["rate"]=="-"].index
rate_hyphen
# Out:
# Int64Index([ 3068,  3069,  3373,  3378,  3387,  3396,  3397,  3398,  3408,
#              3409,  3410,  3430,  3431,  3432,  3433,  3434, 15959, 18601,
#             18602, 18604, 22458, 33403, 33404, 33405, 33406, 33407, 33408,
#             33409, 33410, 33411, 33412, 33413, 33414, 33418, 33419, 33420,
#             33421, 33422, 33423, 33424, 33425, 33426, 33427, 33428, 33429,
#             33430, 33431, 33432, 33433, 33434, 33435, 33436, 33437, 33438,
#             33439, 33440, 33441, 33442, 33443, 33444, 33445, 33446, 33447,
#             33448, 33454, 33463, 45646, 45647, 48139],
#            dtype='int64')

# %%
df.drop(rate_hyphen, axis = 0, inplace = True)

# %%
df["rate"].isnull().sum()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df["rate"].replace({"NEW": "2.5 /5"}, inplace=True)
df["rate"].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.5 /5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df["rate"] = df["rate"].apply(lambda x : x.split("/")[0])
df["rate"] = df["rate"].apply(lambda x : x.split(" ")[0])
df["rate"].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '2.5', '2.9', '3.5',
#        '2.6', '3.4', '4.5', '2.7', '4.7', '2.4', '2.2', '2.3', '4.8',
#        '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
df["location"].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', nan, 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Sarjapur Road', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Whitefield', 'East Bangalore', 'Old Airport Road',
#        'Indiranagar', 'Koramangala 1st Block', 'Frazer Town', 'RT Nagar',
#        'MG Road', 'Brigade Road', 'Lavelle Road', 'Church Street',
#        'Ulsoor', 'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road',
# ...

# %%
len(df["location"].unique())
# Out:
# 94

# %%
df = df.dropna(subset = ["location"])
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
# df_kor = df[df["location"].str.contains("Koramangala")]
# df_kor_list = df_kor["location"].unique()
# df["location"] = df["location"].replace(df_kor_list, "Koramanagala")

# %%
df["rest_type"].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', nan, 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
# ...

# %%
df = df.dropna(subset=["rest_type"])

# %%
df["rest_type"].isnull().sum()
# Out:
# 0

# %%
df["dish_liked"].unique()
# Out:
# array(['Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#        'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#        'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#        ...,
#        'Noodles, Chicken Noodle, Momos, American Chopsuey, Salad, Manchow Soup, Manchurian',
#        'Chicken Quesadilla, Naan, Breakfast Buffet, Cheesecake, Cocktails, Lunch Buffet, Biryani',
#        'Biryani, Andhra Meal'], dtype=object)

# %%
df["dish_liked"] = df["dish_liked"].fillna("NONE")
# Out:
# C:\Users\khush\AppData\Local\Temp/ipykernel_17052/3515683058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["dish_liked"] = df["dish_liked"].fillna("NONE")

# %%
df["dish_liked"].isnull().sum()
# Out:
# 0

# %%
df["dish_liked"]
# Out:
# 0        Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2        Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                              Masala Dosa
# 4                                      Panipuri, Gol Gappe
#                                ...
# 51712                                                 NONE
# 51713                                                 NONE
# 51714                                                 NONE
# 51715                         Cocktails, Pizza, Buttermilk
# 51716                                                 NONE
# Name: dish_liked, Length: 51421, dtype: object

# %%
df["cuisines"].isnull().sum()
# Out:
# 24

# %%
df = df.dropna(subset=["cuisines"])

# %%
df["cuisines"].isnull().sum()
# Out:
# 0

# %%
df["approx_cost(for two people)"]
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51712    1,500
# 51713      600
# 51714    2,000
# 51715    2,500
# 51716    1,500
# Name: approx_cost(for two people), Length: 51397, dtype: object

# %%
df = df.rename(columns={"approx_cost(for two people)": "cost"})

# %%
df["cost"].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '6,000', '1,050', '2,300', '4,100', '5,000',
#        '3,700', '1,650', '2,700', '4,500', '140', '360'], dtype=object)

# %%
df["cost"] = [float(str(i).replace(",", "")) for i in df["cost"]]
df["cost"].unique()
df["cost"].dropna()
df = df.dropna(subset= ["cost"])
df["cost"].isnull().sum()
# Out:
# 0

# %%
df["listed_in(type)"].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
plt.figure(figsize= (18, 12))
sns.boxplot(x="listed_in(type)", y="cost", data=df)
# Out:
# <AxesSubplot:xlabel='listed_in(type)', ylabel='cost'>

# %%
df["rate"] = [float(i) for i in df["rate"]]
df["rate"].unique()
# Out:
# C:\Users\khush\AppData\Local\Temp/ipykernel_17052/2406829719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rate"] = [float(i) for i in df["rate"]]
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.5, 2.9, 3.5, 2.6, 3.4, 4.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %%
plt.figure(figsize= (18, 12))
sns.boxplot(x="listed_in(type)", y= "rate", data=df)
# Out:
# <AxesSubplot:xlabel='listed_in(type)', ylabel='rate'>

# %%
plt.figure(figsize= (180, 12))
sns.boxplot(x="location", y= "rate", data=df)
# Out:
# <AxesSubplot:xlabel='location', ylabel='rate'>

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df_rest = df[['name', 'location', "rest_type"]]
df_rest = df_rest.reindex(range(0,len(df_rest)))
df_rest
# Out:
#                                                     name      location  \
# 0                                                  Jalsa  Banashankari
# 1                                         Spice Elephant  Banashankari
# 2                                        San Churro Cafe  Banashankari
# 3                                  Addhuri Udupi Bhojana  Banashankari
# 4                                          Grand Village  Basavanagudi
# ...                                                  ...           ...
# 51078                               Toscano - Mojito Bar    Whitefield
# 51079  Uppercut - Sheraton Grand Bengaluru Whitefield...    Whitefield
# 51080                                 Imperio Restaurant    Whitefield
# 51081                                           Galito's    Whitefield
# 51082                                      Beijing Bites    Whitefield
#
#                  rest_type
# 0            Casual Dining
# 1            Casual Dining
# 2      Cafe, Casual Dining
# ...

# %%
print(len(df_rest["rest_type"].unique()))
df_rest['rest_type'].unique()
# Out:
# 94
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', nan, 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', 'Dhaba', 'Quick Bites, Sweet Shop',
#        'Microbrewery', 'Food Court, Quick Bites', 'Pub, Bar',
# ...

# %%
df_rest.drop_duplicates()
df_rest
# Out:
#                                                     name      location  \
# 0                                                  Jalsa  Banashankari
# 1                                         Spice Elephant  Banashankari
# 2                                        San Churro Cafe  Banashankari
# 3                                  Addhuri Udupi Bhojana  Banashankari
# 4                                          Grand Village  Basavanagudi
# ...                                                  ...           ...
# 51078                               Toscano - Mojito Bar    Whitefield
# 51079  Uppercut - Sheraton Grand Bengaluru Whitefield...    Whitefield
# 51080                                 Imperio Restaurant    Whitefield
# 51081                                           Galito's    Whitefield
# 51082                                      Beijing Bites    Whitefield
#
#                  rest_type
# 0            Casual Dining
# 1            Casual Dining
# 2      Cafe, Casual Dining
# ...

# %%
type_set = set()
def getSet(x):
    if(type(x) == list):
        for y in x:
            type_set.add(y.strip())
b = df_rest["rest_type"].str.split(",").apply(getSet)
type_set
# Out:
# {'Bakery',
#  'Bar',
#  'Beverage Shop',
#  'Bhojanalya',
#  'Cafe',
#  'Casual Dining',
#  'Club',
#  'Confectionery',
#  'Delivery',
#  'Dessert Parlor',
#  'Dhaba',
#  'Fine Dining',
#  'Food Court',
#  'Food Truck',
#  'Irani Cafee',
#  'Kiosk',
#  'Lounge',
#  'Meat Shop',
#  'Mess',
#  'Microbrewery',
#  'Pop Up',
#  'Pub',
#  'Quick Bites',
#  'Sweet Shop',
#  'Takeaway'}

# %%
column_names = list(type_set)
rest_type = pd.DataFrame(columns=column_names)
rest_type
# Out:
# Empty DataFrame
# Columns: [Bar, Fine Dining, Irani Cafee, Pub, Food Truck, Pop Up, Kiosk, Cafe, Quick Bites, Bakery, Delivery, Mess, Dhaba, Meat Shop, Microbrewery, Confectionery, Sweet Shop, Bhojanalya, Takeaway, Lounge, Casual Dining, Beverage Shop, Club, Food Court, Dessert Parlor]
# Index: []
#
# [0 rows x 25 columns]

# %%
# for i in df_rest["location"]:
#     print(type(i))

# %%
# add aggregate function --later
rest_type["location"] = df_rest.groupby("location").groups.keys() 
rest_type = rest_type.set_index("location").fillna(0)
for i in range(0, len(df_rest)):
    for x in type_set:
        if type(df_rest.loc[i, "rest_type"]) == str and x in df_rest.loc[i, "rest_type"]:
            rest_type.loc[df_rest.loc[i, "location"], x] = rest_type.loc[df_rest.loc[i, "location"], x]+1
rest_type
# Out:
#                    Bar  Fine Dining  Irani Cafee  Pub  Food Truck  Pop Up  \
# location
# BTM                 77            0            0   10           0       0
# Banashankari        28            0            0    6           0       0
# Banaswadi           18            0            0    4           0       0
# Bannerghatta Road   10            0            0   18           0       0
# Basavanagudi        19            0            0    4           0       0
# ...                ...          ...          ...  ...         ...     ...
# West Bangalore       0            0            0    0           3       0
# Whitefield          37           11            0   22           0       2
# Wilson Garden        5            0            0    0           0       0
# Yelahanka            0            0            0    0           0       0
# Yeshwantpur          7            0            0    0           0       0
#
# ...

# %%
df_cuisines = df[['name', 'location', 'cuisines']]
df_cuisines = df_cuisines.reindex(range(0, len(df_cuisines)))
df_cuisines = df_cuisines.drop_duplicates()
df_cuisines = df_cuisines.reindex(range(0, len(df_cuisines)))
cuisine_type_set = set()
def getCuisineSet(x):
    if(type(x) == list):
        for y in x:
            cuisine_type_set.add(y.strip())
df_cuisines["cuisines"].str.split(",").apply(getCuisineSet)
print(cuisine_type_set)
# Out:
# {'Tamil', 'Greek', 'Mughlai', 'Middle Eastern', 'Seafood', 'Sandwich', 'Burmese', 'Burger', 'Nepalese', 'Hyderabadi', 'Kerala', 'Mangalorean', 'Chinese', 'BBQ', 'Lucknowi', 'Sri Lankan', 'Bihari', 'Bar Food', 'Indonesian', 'Steak', 'Desserts', 'Bengali', 'South American', 'Chettinad', 'Thai', 'Arabian', 'Beverages', 'Portuguese', 'Kebab', 'Tea', 'Naga', 'European', 'Gujarati', 'Paan', 'South Indian', 'Goan', 'Maharashtrian', 'Italian', 'Singaporean', 'Mexican', 'Andhra', 'Rolls', 'Juices', 'Malaysian', 'Turkish', 'African', 'Indian', 'Assamese', 'Asian', 'Ice Cream', 'Bubble Tea', 'Mediterranean', 'Charcoal Chicken', 'North Indian', 'Awadhi', 'Drinks Only', 'Modern Indian', 'Kashmiri', 'Sushi', 'Spanish', 'North Eastern', 'Konkan', 'Fast Food', 'Bakery', 'Belgian', 'Bohri', 'Mongolian', 'Lebanese', 'Japanese', 'Roast Chicken', 'Coffee', 'Biryani', 'Street Food', 'Grill', 'French', 'Mithai', 'Pizza', 'Korean', 'American', 'Tibetan', 'Rajasthani', 'Salad', 'Afghan', 'Hot dogs', 'Cafe',
# ...

# %%
column_names = list(cuisine_type_set)
cuisines_type = pd.DataFrame(columns = column_names)
cuisines_type
# Out:
# Empty DataFrame
# Columns: [Tamil, Greek, Mughlai, Middle Eastern, Seafood, Sandwich, Burmese, Burger, Nepalese, Hyderabadi, Kerala, Mangalorean, Chinese, BBQ, Lucknowi, Sri Lankan, Bihari, Bar Food, Indonesian, Steak, Desserts, Bengali, South American, Chettinad, Thai, Arabian, Beverages, Portuguese, Kebab, Tea, Naga, European, Gujarati, Paan, South Indian, Goan, Maharashtrian, Italian, Singaporean, Mexican, Andhra, Rolls, Juices, Malaysian, Turkish, African, Indian, Assamese, Asian, Ice Cream, Bubble Tea, Mediterranean, Charcoal Chicken, North Indian, Awadhi, Drinks Only, Modern Indian, Kashmiri, Sushi, Spanish, North Eastern, Konkan, Fast Food, Bakery, Belgian, Bohri, Mongolian, Lebanese, Japanese, Roast Chicken, Coffee, Biryani, Street Food, Grill, French, Mithai, Pizza, Korean, American, Tibetan, Rajasthani, Salad, Afghan, Hot dogs, Cafe, Momos, Afghani, Continental, Healthy Food, Vietnamese, Finger Food, Oriya, Tex-Mex, Iranian, Parsi, Australian, Cantonese, Wraps]
# Index: []
# ...

# %%
cuisines_type['location'] = df_cuisines.groupby('location').groups.keys()
cuisines_type = cuisines_type.set_index('location').fillna(0)
i = 0
for i in range(0,len(df_cuisines)):
    for x in cuisine_type_set:
        if type(df_cuisines.loc[i, 'cuisines']) == str and x in df_cuisines.loc[i, 'cuisines']:
            cuisines_type.loc[df_cuisines.loc[i, 'location'], x] = cuisines_type.loc[df_cuisines.loc[i, 'location'], x]+1

# %%
cuisines_type
# Out:
#                                Tamil  Greek  Mughlai  Middle Eastern  Seafood  \
# location
# BTM                                0      0       11               2       15
# Banashankari                       0      0        4               0        6
# Bannerghatta Road                  0      0       10               1       18
# Basavanagudi                       0      0        4               0        3
# Bellandur                          1      0       11               0        4
# ...                              ...    ...      ...             ...      ...
# Varthur Main Road, Whitefield      0      0        1               3        6
# Vasanth Nagar                      0      0        2               0        1
# Vijay Nagar                        0      0        0               0        1
# Whitefield                         0      0       14               0        7
# Wilson Garden                      0      0        0               0        0
#
# ...

# %%
cuisines_type.sum()
# Out:
# Tamil               3
# Greek               2
# Mughlai           182
# Middle Eastern     14
# Seafood           206
#                  ...
# Iranian             3
# Parsi               2
# Australian          1
# Cantonese           1
# Wraps               5
# Length: 98, dtype: int64

# %%
cuisines_data = pd.DataFrame(cuisines_type.sum(axis=0))
cuisines_data
# Out:
#                   0
# Tamil             3
# Greek             2
# Mughlai         182
# Middle Eastern   14
# Seafood         206
# ...             ...
# Iranian           3
# Parsi             2
# Australian        1
# Cantonese         1
# Wraps             5
#
# [98 rows x 1 columns]

# %%
cuisines_data.reset_index(inplace=True)
cuisines_data.columns = ["Cuisines", "Number of Restaurants"]
top20_cuisines = (cuisines_data.sort_values(["Number of Restaurants"], ascending=False)).head(20)
sns.barplot(top20_cuisines["Cuisines"], top20_cuisines["Number of Restaurants"])
plt.xlabel("Cuisines", fontsize=20)
plt.ylabel("Number of Restaurants", fontsize=20)
plt.title("Top 20 Cuisines", fontsize=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
rest_data = pd.DataFrame(rest_type.sum(axis=0))
rest_data
# Out:
#                     0
# Bar              2371
# Fine Dining       394
# Irani Cafee        15
# Pub               917
# Food Truck         82
# Pop Up              2
# Kiosk             181
# Cafe             5008
# Quick Bites     20205
# Bakery           1979
# Delivery         4576
# Mess              262
# Dhaba              38
# Meat Shop           4
# Microbrewery      366
# Confectionery      47
# Sweet Shop        742
# Bhojanalya          2
# Takeaway         2124
# Lounge            534
# Casual Dining   12781
# Beverage Shop    1454
# Club               41
# Food Court        719
# Dessert Parlor   3186

# %%
rest_data.reset_index(inplace=True)
rest_data.columns = ["rest_type", "Number of Restaurants"]
top20_rest = (rest_data.sort_values(["Number of Restaurants"], ascending=False)).head(20)
sns.barplot(top20_rest["rest_type"], top20_rest["Number of Restaurants"])
plt.xlabel("rest_type", fontsize=20)
plt.ylabel("Number of Restaurants", fontsize=20)
plt.title("Top 20 rest_type on Zomato", fontsize=30)
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top20_rest
# Out:
#          rest_type  Number of Restaurants
# 8      Quick Bites                  20205
# 20   Casual Dining                  12781
# 7             Cafe                   5008
# 10        Delivery                   4576
# 24  Dessert Parlor                   3186
# 0              Bar                   2371
# 18        Takeaway                   2124
# 9           Bakery                   1979
# 21   Beverage Shop                   1454
# 3              Pub                    917
# 16      Sweet Shop                    742
# 23      Food Court                    719
# 19          Lounge                    534
# 1      Fine Dining                    394
# 14    Microbrewery                    366
# 11            Mess                    262
# 6            Kiosk                    181
# 4       Food Truck                     82
# 15   Confectionery                     47
# 22            Club                     41

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.isnull().sum()
# Out:
# url                  0
# address              0
# name                 0
# online_order         0
# book_table           0
# rate                 0
# votes                0
# phone              869
# location             0
# rest_type            0
# dish_liked           0
# cuisines             0
# cost                 0
# reviews_list         0
# menu_item            0
# listed_in(type)      0
# listed_in(city)      0
# dtype: int64

# %%
df_recommendation = df.copy()
df_recommendation = df_recommendation.drop(["phone", "menu_item"], axis=1)
df_recommendation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51083 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              51083 non-null  object
#  1   address          51083 non-null  object
#  2   name             51083 non-null  object
#  3   online_order     51083 non-null  object
#  4   book_table       51083 non-null  object
#  5   rate             51083 non-null  float64
#  6   votes            51083 non-null  int64
#  7   location         51083 non-null  object
#  8   rest_type        51083 non-null  object
#  9   dish_liked       51083 non-null  object
#  10  cuisines         51083 non-null  object
#  11  cost             51083 non-null  float64
#  12  reviews_list     51083 non-null  object
#  13  listed_in(type)  51083 non-null  object
#  14  listed_in(city)  51083 non-null  object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 8.3+ MB

# %%
restaurants = list(df_recommendation["name"].unique())
df_recommendation["Mean Rating"] = 0 
for i in range(len(restaurants)):
    df_recommendation["Mean Rating"][df_recommendation["name"] == restaurants[i]] = df_recommendation["rate"][df_recommendation["name"] == restaurants[i]].mean()
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (1,5))
df_recommendation[["Mean Rating"]] = scaler.fit_transform(df_recommendation[["Mean Rating"]]).round(2)
df_recommendation[["name", "rate", "Mean Rating"]].head()
# Out:
# C:\Users\khush\AppData\Local\Temp/ipykernel_17052/4047312019.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recommendation["Mean Rating"][df_recommendation["name"] == restaurants[i]] = df_recommendation["rate"][df_recommendation["name"] == restaurants[i]].mean()
# C:\Users\khush\AppData\Local\Temp/ipykernel_17052/4047312019.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recommendation["Mean Rating"][df_recommendation["name"] == restaurants[i]] = df_recommendation["rate"][df_recommendation["name"] == restaurants[i]].mean()
#                     name  rate  Mean Rating
# ...

# %%
df_recommendation["review_list"] = df_recommendation["reviews_list"].str.lower()

import string
PUNCT_TO_REMOVE = string.punctuation
def removePunctuation(text):
    return text.translate(str.maketrans("", "", PUNCT_TO_REMOVE))
df_recommendation["reviews_list"] = df_recommendation["review_list"].apply(lambda text: removePunctuation(text))


import re
def removeURLs(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)
df_recommendation["reviews_list"] = df_recommendation["reviews_list"].apply(lambda text: removeURLs(text))

import nltk
# nltk.download("stopwords")
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df_recommendation["reviews_list"] = df_recommendation["reviews_list"].apply(lambda text: remove_stopwords(text))
df_recommendation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\khush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# ...

# %%
df_recommendation.drop(["address", "rest_type", "votes", "listed_in(type)"], axis=1)
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df_percent = df_recommendation.sample(frac=0.5)
df_percent
# Out:
#                                                      url  \
# 6622   https://www.zomato.com/bangalore/capri-gastrob...
# 35195  https://www.zomato.com/bangalore/the-kitchen-s...
# 20675  https://www.zomato.com/bangalore/alfa-family-r...
# 37652  https://www.zomato.com/bangalore/lounge-189-hs...
# 10152  https://www.zomato.com/bangalore/diyas-findish...
# ...                                                  ...
# 41438  https://www.zomato.com/bangalore/kantis-marath...
# 3640   https://www.zomato.com/bangalore/ande-ka-funda...
# 26608  https://www.zomato.com/bangalore/tattva-cafe-k...
# 2965   https://www.zomato.com/bangalore/chungs-chines...
# 21699  https://www.zomato.com/bangalore/jordan-cafe-b...
#
#                                                  address  \
# 6622   2nd Floor, 17/22, Vasavi Complex, St. Marks Ro...
# 35195  17th Cross, Rajeev Gandhi Nagar, Sector 6, HSR...
# 20675  44/3, 10th Cross, 1st Main, Arekempanahalli, S...
# ...

# %%
df_percent = df_percent.set_index(['name'], inplace=False)

# %%
indices = pd.Series(df_percent.index)

# %%
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['reviews_list'])

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend(name, cosine_similarities = cosine_similarities):
    
    # Create a list to put top restaurants
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = indices[indices == name].index[0]
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['cuisines', 'Mean Rating', 'cost'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_percent[['cuisines','Mean Rating', 'cost']][df_percent.index == each].sample()))
    
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['cuisines','Mean Rating', 'cost'], keep=False)
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(10)
    
    print('TOP %s RESTAURANTS LIKE %s WITH SIMILAR REVIEWS: ' % (str(len(df_new)), name))
    
    return df_new

# %%
recommend("Truffles")
# Out:
# TOP 10 RESTAURANTS LIKE Truffles WITH SIMILAR REVIEWS:
#                                                                       cuisines  \
# Byg Brewski Brewing Company  Continental, North Indian, Italian, South Indi...
# The Pizza Bakery                                     Italian, Pizza, Beverages
# Koramangala Social                American, North Indian, Chinese, Finger Food
# Chianti                                                                Italian
# Bologna                                                                Italian
# Stoner                       Ice Cream, Cafe, Beverages, Burger, Desserts, ...
# Biergarten                   Continental, North Indian, Chinese, European, ...
# Stories                           American, Chinese, Continental, North Indian
# Church Street Social         American, North Indian, Chinese, Finger Food, ...
# Marzipan Cafe & Bakery           Cafe, Mediterranean, Bakery, Greek, Beverages
#
# ...

# %%
df_percent[df_percent.index=="Truffles"].head()
# Out:
#                                                         url  \
# name
# Truffles  https://www.zomato.com/bangalore/truffles-st-m...
# Truffles  https://www.zomato.com/bangalore/truffles-st-m...
# Truffles  https://www.zomato.com/bangalore/truffles-kaly...
# Truffles  https://www.zomato.com/bangalore/truffles-st-m...
# Truffles  https://www.zomato.com/bangalore/truffles-indi...
#
#                                                     address online_order  \
# name
# Truffles                      22, St. Marks Road, Bangalore           No
# Truffles                      22, St. Marks Road, Bangalore           No
# Truffles  5M 408, Ground Floor, 5th Main, HRBR Layout, K...           No
# Truffles                      22, St. Marks Road, Bangalore           No
# Truffles   1st Stage, 100 feet Road, Indiranagar, Bangalore           No
#
#          book_table  rate  votes        location            rest_type  \
# name
# Truffles         No   4.5   3599  St. Marks Road                 Cafe
# ...
